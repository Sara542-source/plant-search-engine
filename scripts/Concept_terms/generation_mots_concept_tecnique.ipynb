# %%
import json
import os
from typing import Set, Dict, Any

# =========================================================================
# 1. DONNÉES ET CONFIGURATION
# =========================================================================

# Le dictionnaire de concepts que vous avez fourni (avec les verbes ajoutés)
CONCEPTS_CLES_HORTICOLES_DICT: Dict[str, Any] = {
    "concepts_cles_horticoles": {
        "1_Arrosage": [
            "arrosage", "arroser", "eau", "hydrique", "irrigation", "bassinage", "brumisation", "mouillage", "irriguer", "humidifier"
        ],
        "2_Luminosite": [
            "luminosité", "lumière", "lumineux", "intensité", "radiation", "photon", "éclairage", "éclairer", "illuminer"
        ],
        "3_Types_de_sol_substrat": [
            "sol", "substrat", "terre", "terreau", "tourbe", "argile", "limon", "sable", "humus", "sphaigne", "vermiculite", "perlite", "mélange", "compact", "compacter", "compaction", "texture", "terreautage"
        ],
        "4_pH_du_sol": [
            "ph", "acide", "acidité", "acidification", "acidophile", "alcalin", "alcalinité", "calcaire", "neutre", "chaux", "acidifier"
        ],
        "5_Temperature": [
            "température", "chaud", "chaleur", "froid", "thermique", "canicule", "gel", "vernalisation", "été", "hiver", "tempéré", "réchauffer", "refroidir"
        ],
        "6_Humidite_ambiante": [
            "humidité", "humide", "hygrométrie", "hygrophyte", "vapeur", "atmosphère", "vaporiser"
        ],
        "7_Engrais_nutrition_NPK": [
            "engrais", "nutriment", "nutrition", "npk", "azote", "azoté", "nh", "nitrate", "phosphore", "phosphoré", "p2o5", "potassium", "potasse", "potassique", "k2o", "calcium", "calcique", "ca", "magnésium", "magnésien", "mg", "fer", "ferrique", "fe", "cuivre", "chélate", "sous-alimentation", "carence", "enrichi", "assimilation", "uptake", "foliaire", "fertigation", "organique", "minéral", "fertiliser", "enrichir", "assimiler", "nutrir"
        ],
        "8_Rempotage": [
            "rempotage", "dépotage", "empotage", "transplantation", "transplanter", "rempoter", "dépoter", "empoter"
        ],
        "9_Plantation": [
            "plantation", "planter", "mise en terre", "semis", "semer", "levée", "cotylédon", "embryon"
        ],
        "10_Drainage": [
            "drainage", "drainer", "percolation", "évacuation", "porosité", "pore", "micropore", "macropore", "percoler", "évacuer"
        ],
        "11_Propagation_reproduction": [
            "propagation", "reproduction", "semer", "semis", "semence", "bouturage", "bouture", "bouture de feuille", "bouture de tige", "greffage", "greffe", "greffon", "porte-greffe", "division", "diviser", "marcottage", "marcotte", "rhizome", "hybridation", "hybride", "f1", "ovule", "zygote", "gamète", "autopollinisation", "allogamie", "fécondation", "propager", "reproduire", "greffer", "marcotter", "hybrider", "féconder"
        ],
        "12_Taille_et_elagage": [
            "taille", "tailler", "élagage", "élagueur", "rabattage", "pincement", "coupe", "nettoyage", "élaguer", "rabattre", "pincer", "couper", "nettoyer"
        ],
        "13_Maladies_fongiques": [
            "maladie", "fongique", "fongicide", "fungicide", "mildiou", "downy", "oïdium", "powdery", "botrytis", "fusariose", "rouille", "erisiphe", "plasmopara", "virus", "bactérie", "infecter", "contaminer"
        ],
        "14_Parasites_courants": [
            "parasite", "parasites", "puceron", "aphid", "cochenille", "farineuse", "mealybug", "aleurode", "whiteflie", "trialeurodes", "thrips", "frankliniella", "tétranyque", "araignée", "acarien", "nématode", "mouche", "mite", "larve", "larvicide", "insecticide", "acaricide", "bio", "biocontrôle", "biologique", "auxiliaire", "coccinelle", "chrysope", "adalia", "bipunctata", "prédateur", "lutte", "parasiter", "infester", "lutter", "prédater"
        ],
        "15_Toxicite": [
            "toxicité", "toxique", "vénéneux", "poison", "intoxication", "thérapeutique", "empoisonner", "intoxiquer"
        ],
        "16_Croissance_et_developpement": [
            "croissance", "développement", "pousse", "bourgeon", "bouton floral", "débourrement", "allongement", "élongation", "maturation", "mature", "mûrir", "maturité", "fructification", "fructifier", "floraison", "fleurir", "anthèse", "hormone", "auxine", "iaa", "gibbérelline", "cytokinine", "éthylène", "photomorphogenèse", "croître", "développer", "mûrir", "fructifier", "fleurir", "pousser"
        ],
        "17_Stress": [
            "stress", "déshydratation", "déficit", "déficience", "défense", "oxydatif", "immunité", "résistance", "résister", "tolérance", "tolérant", "tolérer", "tache", "jaunissement", "décoloration", "décolorer", "nécrose", "nécroser", "nécrotique", "chlorose", "chlorotique", "marbrure", "flétrissement", "flétrir", "fané", "brunissement", "brûler", "brûlure", "coup de soleil", "décomposition", "déshydrater", "résister", "tolérer", "décolorer", "nécroser", "brûler", "décomposer", "jaunir", "flétrir"
        ],
        "18_Cycle_de_vie": [
            "annuel", "annuelle", "vivace", "pérenne", "arbuste", "arbrisseau", "arbre", "conifère", "dormance", "dormant", "repos", "quiescence", "sénescence", "vieillir"
        ],
        "19_Origine_geographique_biomes": [
            "origine", "originaire", "indigène", "natif", "endémique", "introduit", "invasif", "envahissant", "biome", "biomes", "tropical", "tropicale", "équatorial", "désert", "aride", "mousson", "savane", "toundra", "forêt", "forestier", "garrigue", "maquis", "méditerranéen", "subméditerranéen", "xérophyte", "rudérale", "introduire", "envahir"
        ],
        "20_Technologies_horticoles_modernes": [
            "automate", "automatique", "automatisation", "robotique", "iot", "connecté", "programmable", "sensor", "capteur", "sonde", "wireless", "led", "diode", "éclairage", "télédétection", "télésurveillance", "hydroponie", "aéroponie", "nft", "dwc", "automatiser", "connecter", "programmer", "détecter", "surveiller"
        ]
    }
}

OUTPUT_FILE = '../../docs/mot_conceptuel/protected_concepts.json'

# =========================================================================
# 2. FONCTION DE CONSOLIDATION ET DE SAUVEGARDE
# =========================================================================

def generate_concept_terms_set(concepts_dict: dict) -> Set[str]:
    """
    Consolide tous les termes des catégories en un seul ensemble (Set).
    """
    final_set = set()
    
    # Parcourir chaque catégorie du dictionnaire
    # Note: On accède à 'concepts_cles_horticoles' qui est la clé du dictionnaire racine
    for categorie, termes in concepts_dict['concepts_cles_horticoles'].items():
        for terme in termes:
            # Normaliser le terme (minuscules, supprimer espaces inutiles)
            final_set.add(terme.lower().strip())
            
    return final_set

def save_concept_terms(concepts_dict: dict, output_path: str):
    """
    Génère l'ensemble de termes, le trie, et le sauvegarde en JSON.
    """
    # 1. Générer l'ensemble de termes
    concept_set = generate_concept_terms_set(concepts_dict)
    
    # 2. Préparer la structure de sortie (liste triée)
    output_data = {
        "concepts": sorted(list(concept_set)),
        "count": len(concept_set)
    }
    
    # 3. Créer le répertoire si nécessaire
    output_dir = os.path.dirname(output_path)
    if output_dir and not os.path.exists(output_dir):
        os.makedirs(output_dir)
        print(f"📁 Répertoire créé : {output_dir}")
    
    # 4. Sauvegarde en JSON
    try:
        with open(output_path, 'w', encoding='utf-8') as f:
            # Utilisation d'ensure_ascii=False pour gérer correctement les accents et autres caractères
            json.dump(output_data, f, indent=4, ensure_ascii=False)
            
        print(f"\n✅ Succès : {output_data['count']} termes de concepts clés sauvegardés.")
        print(f"   Fichier de pondération enregistré : {output_path}")
        
    except IOError as e:
        print(f"❌ Erreur lors de l'écriture du fichier : {e}")

# =========================================================================
# 3. EXÉCUTION
# =========================================================================

if __name__ == "__main__":
    save_concept_terms(CONCEPTS_CLES_HORTICOLES_DICT, OUTPUT_FILE)
